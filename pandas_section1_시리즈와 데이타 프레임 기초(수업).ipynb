# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 판다스 API : https://pandas.pydata.org/pandas-docs/stable/reference/index.html
# - 넘파이 API : https://numpy.org/doc/stable/reference/index.html
# - Python for Data Analysis(3판) : https://wesmckinney.com/book/

# %% [markdown]
# #데이터 분석에 유용한 Pandas
# * 데이터를 효과적으로 처리하고, 보여줄 수 있도록 도와주는 라이브러리이다.
# * Numpy와 함께 사용되어 다양한 연계적인 기능을 제공한다.
# * 인덱스(Index)에 따라 데이타를 나열하므로 사전(Dictionary) 자료형에 가깝다.
# * 시리즈(Series)를 기본적인 자료형으로 사용한다.
# * 엑셀(Excel)과 거의 똑같다.
# * 판다스는 숫자만 사용하는 넘파이와는 달리 문자, 숫자 등 다양한 자료형을 갖는 데이터들을 한꺼번에 수정, 재배치, 연산할 수 있는 라이브러리이다.
# * 판다스에서는 데이터 배열을 시리즈 또는 데이터프레임이라고 부른다.
# * 시리즈는 넘파이의 벡터와 같은 1차원 형태이고, 데이터프레임은 넘파이의 행렬과 같은 2차원 형태를 의미한다.

# %% [markdown]
# * 데이터프레임(DataFrame) : 데이터 테이블 전체 객체
# * 시리즈(Series) : 각 열 데이터를 다루는 객체

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# [0] pandas 설치
# !pip install pandas

# %%
# 판다스 라이브러리를 불러와 pd라는 별명으로 사용
import pandas as pd
pd.__version__
# Out:
# '2.0.3'

# %% [markdown]
# #시리즈 생성
#
# * 시리즈 생성의 기본은 Series( ) 함수이다.
# * 판다스 객체는 앞에서 설정한 ‘pd’를 사용하고, 리스트와 딕셔너리를 전달하여 만들 수 있다

# %% [markdown]
# ## 리스트를 전달하여 시리즈 생성
# * ( ) 안의 [ ]는 Python 리스트이고, 인덱스 리스트를 생략하면 0부터 시작하는 정수형으로 생성한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# index 생략하여 Series 생성
data_list = ['2020','2021','2022','20203']
s = pd.Series(data_list)
s
# Out:
# 0     2020
# 1     2021
# 2     2022
# 3    20203
# dtype: object

# %%
type(s)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# index 지정하여 Series 생성
data_list = [5,6,12,-5,6.7]
data_index =['A','B','C','D','E']

s1 = pd.Series(data_list,index=data_index)
s1
# Out:
# A     5.0
# B     6.0
# C    12.0
# D    -5.0
# E     6.7
# dtype: float64

# %%
s2 = pd.Series(data=[5,6,12,-5,6.7],index=['A','B','C','D','E'])
s2
# Out:
# A     5.0
# B     6.0
# C    12.0
# D    -5.0
# E     6.7
# dtype: float64

# %% [markdown]
# * Series 객체의 인덱스(index)
# * Series 객체의 모든 데이터 값(values)
# * Series 객체의 이름 지정하기(name)
# * Series 객체의 인덱스명 지정하기

# %%
dir(s1)

# %%
# index 확인
s1.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
# value 확인
s1.values
# Out:
# array([ 5. ,  6. , 12. , -5. ,  6.7])

# %%
# 특정값 value 확인 -> list index 방식과 동일
s1.values[1]
# Out:
# 6.0

# %%
# 특정값 value 확인 -> list slicing 방식과 동일
s1.values[1:3]
# Out:
# array([ 6., 12.])

# %%
# values datatype 확인
type(s1.values) #넘파이 배열(numpy.ndarray) 타입
# Out:
# numpy.ndarray

# %%
# 값 변경 -> Series의 index로 접근
s1['C'] = 10
s1
# Out:
# A     5.0
# B     6.0
# C    10.0
# D    -5.0
# E     6.7
# dtype: float64

# %%
# Series의 index slicing으로 조회
#index dtype이 object이면 끝값 포함, 숫자형이면 미포함
s1['B':'D']
# Out:
# B     6.0
# C    10.0
# D    -5.0
# dtype: float64

# %%
# Series의 index를 여러개 지정하여 조회
s1[['A','C','E']]
# Out:
# A     5.0
# C    10.0
# E     6.7
# dtype: float64

# %%
# Series 객체의 이름 지정하기(name)

s1.name = 'number'
s1
# Out:
# A     5.0
# B     6.0
# C    10.0
# D    -5.0
# E     6.7
# Name: number, dtype: float64

# %%
# Series 객체의 인덱스명 지정하기
s1.index.name ='no'
s1
# Out:
# no
# A     5.0
# B     6.0
# C    10.0
# D    -5.0
# E     6.7
# Name: number, dtype: float64

# %% [markdown]
# # 딕셔너리를 전달하여 시리즈 생성
#
# * ( ) 안에 {'a':1, 'b':2, 'c':3}와 같은 딕셔너리 형태를 전달하여 생성한다.
# ![image.png](data:image/png;base64,...)

# %%
data_dict ={'a' : 1, 'b' : 2, 'c' : 3, 'd':4, 'e':5}

s2 = pd.Series(data_dict)
s2
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
# index 확인
s2.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
# value 확인
s2.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
data_dict.keys()
# Out:
# dict_keys(['a', 'b', 'c', 'd', 'e'])

# %%
data_dict.values()
# Out:
# dict_values([1, 2, 3, 4, 5])

# %% [markdown]
# # 튜플을 시리즈로 만들려면?
#
# * Python의 튜플을 시리즈로도 변환 가능
# * 리스트와 방법은 동일

# %%
score = (60,70,12)
s3 = pd.Series(score)
s3
# Out:
# 0    60
# 1    70
# 2    12
# dtype: int64

# %% [markdown]
# # 데이터 프레임
# * 데이터프레임은 여러 개의 시리즈를 모아서 나타낸 것이다.
# * 데이터 분석과 머신러닝에서 데이터를 변형하기 위하여 많이 사용되며 판다스의 핵심이라고 할 수 있다.
# * 표 형태로 데이타를 쉽게 출력하고자 할때 사용

# %%
import pandas as pd

# %% [markdown]
# * 딕셔너리 이용
# * 딕셔너리로 데이터프레임을 생성하려면 딕셔너리의 키가 속성명(칼럼명)이 되고 리스트의 요소가 열이 된다.

# %%
# 딕셔너리 형태로 데이터 구성하기
data_dict = {'name': ['Lee','Hwang','kim','Choi'],
             'scose' : [100,90,95,85],
             'grade' : ['A','A','B','B']}
df = pd.DataFrame(data_dict)

df
# Out:
#     name  scose grade
# 0    Lee    100     A
# 1  Hwang     90     A
# 2    kim     95     B
# 3   Choi     85     B

# %%
# column 지정하여 DataFrame 객체 생성
# NaN 행/열 생성시 지정된 값이 없다면 NaN으로 채워짐(Not a Number)

cols = ['name','score','grade','etc']

df2 = pd.DataFrame(data_dict, columns=cols)
df2
# Out:
#     name score grade  etc
# 0    Lee   NaN     A  NaN
# 1  Hwang   NaN     A  NaN
# 2    kim   NaN     B  NaN
# 3   Choi   NaN     B  NaN

# %% [markdown]
# * 리스트를 데이터프레임으로 변환
# * 인덱스(행)와 칼럼(열)이 자동으로 0부터 시작하는 정수로 생성

# %%
# 리스트 형태로 데이터 구성하기
# Out:
#        0    1  2
# 0    Lee  100  A
# 1  Hwang   90  A
# 2    kim   95  B
# 3   Choi   85  B

# %%
# columns명을 데이타프레임 생성 후 지정
# Out:
#     name  score grade
# 0    Lee    100     A
# 1  Hwang     90     A
# 2    kim     95     B
# 3   Choi     85     B

# %%
# 리스트 형태로 데이터 구성하기 + columns 지정
# Out:
#     name  score grade
# 0    Lee    100     A
# 1  Hwang     90     A
# 2    kim     95     B
# 3   Choi     85     B

# %% [markdown]
# * 시리즈 이용
# * 시리즈를 이용하여 데이터프레임을 생성하려면 각 데이터를 시리즈로 만들고, data를 시리즈 리스트로 전달

# %%
a = pd.Series(['Lee',  100, 'A'], index=['name', 'score', 'grade'])
b = pd.Series(['Hwang', 90, 'A'], index=['name', 'score', 'grade'])
c = pd.Series(['kim',   95, 'B'], index=['name', 'score', 'grade'])
d = pd.Series(['Choi',  85, 'B'], index=['name', 'score', 'grade'])

# 데이터프레임 생성
# Out:
#     name  score grade
# 0    Lee    100     A
# 1  Hwang     90     A
# 2    kim     95     B
# 3   Choi     85     B

# %%
# 데이타프레임 확인
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# DataFrame 객체의 index
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
# DataFrame 객체의 column
df.columns
# Out:
# Index(['name', 'scose', 'grade'], dtype='object')

# %%
# DataFrame 객체의 value
df.values
# Out:
# array([['Lee', 100, 'A'],
#        ['Hwang', 90, 'A'],
#        ['kim', 95, 'B'],
#        ['Choi', 85, 'B']], dtype=object)

# %%
# DataFrame 객체의 data type
df.dtypes
# Out:
# name     object
# scose     int64
# grade    object
# dtype: object

# %%
# DataFrame 객체 속성 변경(index, columns)
df.index.name = 'NO'
df.columns.name = 'Info'
df
# Out:
# Info   name  scose grade
# NO
# 0       Lee    100     A
# 1     Hwang     90     A
# 2       kim     95     B
# 3      Choi     85     B

# %%
# DataFrame 객체 columns명 변경
df.columns = ['이름','점수','등급']
df
# Out:
#        이름   점수 등급
# NO
# 0     Lee  100  A
# 1   Hwang   90  A
# 2     kim   95  B
# 3    Choi   85  B

# %%
df
# Out:
#        이름   점수 등급
# NO
# 0     Lee  100  A
# 1   Hwang   90  A
# 2     kim   95  B
# 3    Choi   85  B

# %%
# # DataFrame 객체 columns명 변경 적용 inplace=True
# Out:
# Info     이름  score grade
# NO
# 0       Lee    100     A
# 1     Hwang     90     A
# 2       kim     95     B
# 3      Choi     85     B

# %% [markdown]
# ###  칼럼(열) 데이타 접근
# * 하나의 칼럼 가져오기 :칼럼 단위의 데이터에 접근하기 위해서 기본적으로는 대괄호([ ])를 사용
# 대괄호 안에 칼럼명을 제시

# %% [markdown]
# DataFrame의 한 개의 column은 Series이다.
# - DataFrame[컬럼명] : Series
# - DataFrame[[컬럼명1, 컬럼명2, ...]] : DataFrame

# %%
# score 칼럼 출력
df['이름']
# Out:
# NO
# 0      Lee
# 1    Hwang
# 2      kim
# 3     Choi
# Name: 이름, dtype: object

# %%
# score 칼럼 data type
type(df['이름'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# * 여러개 칼럼 가져오기
# * 데이터프레임에서 여러 개의 칼럼을 가져올 때는 [ ] 안에 칼럼명을 리스트 형태로 나열하여 제시

# %%
# 이름, score  칼럼 확인
df[['이름','점수']]
# Out:
#        이름   점수
# NO
# 0     Lee  100
# 1   Hwang   90
# 2     kim   95
# 3    Choi   85

# %%
# 이름, score  칼럼 data type 확인
type(df[['이름','점수']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ###  데이터프레임에 새로운 칼럼을 추가, 삭제
# * 성별(남성: M, 여성: F)을 나타내는 gender 칼럼을 추가

# %%
# 데이터프레임 객체['새로운 칼럼명'] = 추가할 데이터 값 또는 리스트
df['gender'] =['M','F','M','M']

# %%
df
# Out:
#        이름   점수 등급 gender
# NO
# 0     Lee  100  A      M
# 1   Hwang   90  A      F
# 2     kim   95  B      M
# 3    Choi   85  B      M

# %%
# gender 칼럼을 삭제
# drop(행, axis=0)
# drop(열, axis=1)

df.drop('gender', axis=1)
df
# Out:
#        이름   점수 등급 gender
# NO
# 0     Lee  100  A      M
# 1   Hwang   90  A      F
# 2     kim   95  B      M
# 3    Choi   85  B      M

# %%
del(df['gender'])
df
# Out:
#        이름   점수 등급
# NO
# 0     Lee  100  A
# 1   Hwang   90  A
# 2     kim   95  B
# 3    Choi   85  B

# %% [markdown]
#  * 특정 위치에 칼럼 추가
#
#  * ‘데이터프레임 객체[ ]’ 방식과 다른 점은 추가할 해당 칼럼의 위치를 지정 가능
#   * ‘칼럼 추가 위치’에 0부터 시작하는 칼럼 번호를 입력
#
#
# ![image.png](data:image/png;base64,...)

# %%
# Out:
# Info     이름 gender  score grade
# NO
# 0       Lee      M    100     A
# 1     Hwang      F     90     A
# 2       kim      M     95     B
# 3      Choi      M     85     B

# %%
# 앞에서 추가한 gender 칼럼 삭제(del)
# Out:
# Info     이름  score grade
# NO
# 0       Lee    100     A
# 1     Hwang     90     A
# 2       kim     95     B
# 3      Choi     85     B

# %%
# 인덱스명으로 접근
df.loc[3]
# Out:
# name     Choi
# score      85
# grade       B
# Name: 3, dtype: object

# %%
# 정수형 인덱스로 접근
df.iloc[2]
# Out:
# Info
# score    95
# grade     B
# Name: kim, dtype: object

# %% [markdown]
# ###  데이터프레임에 새로운 행(row)을 추가, 삭제
# * 마지막 위치에 추가 :index 번호 + 1의 위치에 loc 함수를 이용하여 추가

# %%
# Out:
#     name  score grade
# 0    Lee    100     A
# 1  Hwang     90     A
# 2    kim     95     B
# 3   Choi     85     B
# 4    han     55     F

# %% [markdown]
#  * 두 데이터프레임을 이어 붙이는 pd.concat 함수를 사용하여 추가
#  * 데이타 프레임 columns명이 같아야 함

# %%
row_df = pd.DataFrame([['Park', 70, 'C']], columns=['name','score','grade'])
row_df
# Out:
#    name  score grade
# 0  Park     70     C

# %%
df = pd.concat([df, row_df], ignore_index = True)
df
# Out:
#     name  score grade
# 0    Lee    100     A
# 1  Hwang     90     A
# 2    kim     95     B
# 3   Choi     85     B
# 4   Park     70     C

# %%
# index 번호로 삭제
# drop(행, axis=0)
# drop(열, axis=1)
df.drop(df.index[0], axis=0, inplace = True)
df
# Out:
#     name  score grade
# 1  Hwang     90     A
# 3   Choi     85     B
# 4   Park     70     C
